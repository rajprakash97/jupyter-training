# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # markdown basics
#
# ## heading 2
#
# ### heading 3
#
# this is a paragraph
#
# this is another paragraph
#
# this is unordred list:
#
# -item one
# -item 2
# -item 3
#
# this is an ordered list
# 1. item one
# 2. item two
# 3. item 3
#
# this is how you put 'inline' code.
#
# this is how you put an entire code block:
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~.py
# print("hello")
# print("there")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# this is how you [link](C:\Users\Raj\Desktop\DataCS).
#
# this is a image:
#
# [alternate text](C:\Users\Raj\Desktop\DataCS)

# %% [markdown]
# # plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()
plt.plot([1,2,3,4],[1,2,3,4],label="line")

# %%
plt.figure()
plt.plot([1,2,3,4],[1,2,3,4],label="line")
plt.plot([1,2,3,4],[1,4,9,16],label="quadratic")
plt.legend()
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("x vs y")
# Out:
# Text(0.5, 1.0, 'x vs y')

# %%
plt
